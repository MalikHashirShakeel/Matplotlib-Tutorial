# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open('profile.png')

# %%
image_array = np.array(img)

# %%
image_array.shape
# Out:
# (650, 646, 4)

# %%
plt.imshow(img)
plt.show()

# %%
plt.grid(False)
plt.axis("off")
plt.imshow(image_array[10:300, 200:400]);
plt.show()
