# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
xpos = np.arange(4)
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(xpos, company)
# Out:
# ([<matplotlib.axis.XTick at 0x29c73c6cce0>,
# ...
#  [Text(0, 0, 'GOOGL'),
#   Text(1, 0, 'AMZN'),
#   Text(2, 0, 'MSFT'),
#   Text(3, 0, 'FB')])

# %%
plt.title("US tech companies stocks")
plt.xlabel("Companies")
plt.ylabel("Revenue")
plt.bar(company, revenue, width = 0.4)
plt.show()

# %%
profit=[40,2,34,12]

# %%
plt.title("US tech companies stocks")
plt.xlabel("Companies")
plt.ylabel("Revenue")
plt.bar(xpos - 0.15, revenue, width = 0.3, label = "Revenue")
plt.bar(xpos + 0.15, profit, width = 0.3, label = "Profit")
plt.legend()
plt.show()

# %%
plt.yticks(xpos, company)
plt.title("US tech companies stocks")
plt.xlabel("Revenue")
plt.ylabel("Companies")
plt.barh(xpos + 0.15, revenue, height = 0.3, label = "Revenue")
plt.barh(xpos - 0.15, profit, height = 0.3, label = "Profit")
plt.legend(loc = "best", shadow = True, fontsize = "medium")
plt.show()

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(y = "size", x = "day", data = df, hue = "smoker", alpha = 0.8)
plt.show()
